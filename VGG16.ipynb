# %% [markdown]
# <a href="https://colab.research.google.com/github/Babiamba/Neuroniniai-tinklai/blob/main/VGG16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# VGG16

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from google.colab import files
from io import BytesIO
from PIL import Image

# %%
model = keras.applications.VGG16()
# Out:
# ...
# 553476096/553467096 [==============================] - 7s 0us/step

# %%
uploaded = files.upload()
img = Image.open(BytesIO(uploaded['1.jpg']))
plt.imshow( img )
# Out:
#      <input type="file" id="files-83571ccc-4407-422d-943f-2bc3064c1144" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-83571ccc-4407-422d-943f-2bc3064c1144">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1.jpg to 1 (3).jpg

# %%
img = np.array(img)
x = keras.applications.vgg16.preprocess_input(img)
print(x.shape)
x = np.expand_dims(x, axis=0)
# Out:
# (224, 224, 3)

# %%
res = model.predict( x )
print(np.argmax(res))
# Out:
# 207
